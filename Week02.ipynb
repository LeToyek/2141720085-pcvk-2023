# %% [markdown]
# <a href="https://colab.research.google.com/github/LeToyek/2141720085-pcvk-2023/blob/main/Week02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

img = cv.imread('/content/drive/MyDrive/PCVK/katak.jpg')
# plt.imshow(img)
# io.imshow("/content/drive/MyDrive/PCVK/katak.jpg")
# cv2_imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB) # conversi BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/katak.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray,cmap="gray")

# %%
plt.imshow(img_gray,cmap="magma")

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512, 1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3), dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(384,0), pt2=(510,150), color=(0,255,0), thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img, pt1=(200,200), pt2=(300,300), color=(0,0,255), thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img, center=(100,100), radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello', org=(10,500), fontFace=font, fontScale=4, color=(255,255,0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300], [200,200],[400,300],[200,400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2, [pts], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# # Pertanyaan

# %% [markdown]
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
#
# Jawab:
#
# Gambar yang ditampilkan dengan matplotlib akan memiliki sumbu x dan y (plot grafik) yang mewakili pixel pada suatu gambar, sementara gambar yang tidak ditampilkan dengan matplotlib belum tentu memiliki atribut tersebut

# %% [markdown]
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16
# dan int32?
#
# Jawab:
#
# tidak ada perbadaan pengaruh yang dapat langsung dilihat, namun penggunaan tipe data tersebut akan berpengaruh pada penggunaan memori

# %% [markdown]
# 3. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode
# ```python
# from google.colab.patches import cv2_imshow
# from skimage import io
# ```
#
# berikut
#
# Jawab:
# kegunaan dari kode tersebut adalah untuk mengimpor pustaka cv2_imshow dari google.colab.patches. Hal ini digunakan agar program dapat menjalankuan fungsi dari cv2_imshow. Pada kasus di atas, pustaka ini digunakan untuk menampilkan gambar tanpa plot grafik

# %% [markdown]
# 4. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3
#
# Jawab:
#
# hampir sama seperti matplotlib, pustaka tersebut digunakan untuk mengolah gambar seperti menampilkan, menyimpan gambar, hingga melihat informasi setiap pixel dalam gambar

# %% [markdown]
# #Tugas

# %% [markdown]
# 1. Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga
# berubah?
#
# Jawab:
#
# Penggunaan figsize tidak merubah pixel, hanya memperbesar tampilan gambar

# %% [markdown]
# 2. Tampilkan image dalam channel Red-Blue dan Green-Blue saja!

# %%
print("Red - Blue channel only")
rb_img = img.copy()

# dissable green channel
rb_img[:,:,1] = 0

cv2_imshow(rb_img)

print("Green - Blue channel only")

gb_img = img.copy()

# dissable red channel
gb_img[:,:,0] = 0

cv2_imshow(gb_img)
# Out:
# Red - Blue channel only
# <PIL.Image.Image image mode=RGB size=750x500>
# Green - Blue channel only
# <PIL.Image.Image image mode=RGB size=750x500>

# %% [markdown]
# 3. Tampilkan image baris ke 20-115, kolom 25-120!

# %%
start_row = 20
end_row = 115
start_col = 25
end_col = 120
sel_img = img[start_row:end_row,start_col:end_col]

cv2_imshow(sel_img)

# for row in range(start_row, end_row + 1):
#     for col in range(start_col, end_col + 1):
#         pixel = img[row, col]
#         cv2_imshow( pixel)
# Out:
# <PIL.Image.Image image mode=RGB size=95x95>

# %% [markdown]
# 4. Tampilkan image baris ke 5-30, semua kolom, channel Red saja!

# %%
cp_img = img.copy()
all_col_img = cp_img[5:31,:]


all_col_img[:,:,1] = 0 # disable green ch
all_col_img[:,:,0] = 0 # disable blue ch

cv2_imshow(all_col_img)
# Out:
# <PIL.Image.Image image mode=RGB size=750x26>

# %% [markdown]
# 5. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image.
# disarankan menggunakan bilangan acak/random!

# %%
import numpy as np
import random

cp5_img = img.copy()
height,width,_ = cp5_img.shape
image = np.copy(cp5_img)

for i in range(5):
    x1 = random.randint(0, width - 50)
    y1 = random.randint(0, height - 50)
    x2 = x1 + random.randint(20, 100)
    y2 = y1 + random.randint(20, 100)
    color = (random.randint(0, 255), random.randint(0, 255), random.randint(0, 255))

    cv.rectangle(image, (x1, y1), (x2, y2), color, -1)

cv2_imshow( image)
# Out:
# <PIL.Image.Image image mode=RGB size=750x500>

# %% [markdown]
# 6. Tampilkan image dengan posisi terbalik!

# %%
img6 = cv.flip(cp5_img,flipCode=0)

cv2_imshow(img6)
# Out:
# <PIL.Image.Image image mode=RGB size=750x500>

# %% [markdown]
# 7. Buat rectangle dan circle pada bagian wajah dari image foto anda saat
# beraktifitas (bukan pasfoto).

# %%
resImg = cv.imread('/content/drive/MyDrive/PCVK/lomba.JPG')
myImg = cv.cvtColor(resImg, cv.COLOR_BGR2RGB) # conversi BGR -> RGB
cv.circle(myImg, center=(2300,400), radius=250,color=(255,0,0),thickness=24)
cv.rectangle(myImg, pt1=(2100,600), pt2=(2500,200), color=(0,0,255), thickness=15)

plt.imshow(myImg)

# %% [markdown]
# 8. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB
# dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!

# %%
resLenaImg = cv.imread('/content/drive/MyDrive/PCVK/lenna.png')

lenaImg = cv.cvtColor(resLenaImg, cv.COLOR_BGR2RGB)
cv.rectangle(lenaImg, pt1=(0,512), pt2=(100,412), color=(0,0,255), thickness=15)
plt.imshow(lenaImg)

# %% [markdown]
# 9. Lengkapi tulisan nama file pada file citra dari soal no.8. gunakan font, ukuran
# font, dan warna font yang sesuai keinginan anda.

# %%
newFont = cv.FONT_HERSHEY_SIMPLEX
cv.putText(lenaImg,text='edited Lena', org=(10,50), fontFace=newFont, fontScale=2, color=(0,255,255), thickness=4, lineType=cv.LINE_AA)
cv.putText(lenaImg,text='by Maulana Arif', org=(10,90), fontFace=newFont, fontScale=.8, color=(0,255,0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(lenaImg)

# %% [markdown]
# ##Tugas

# %%
ktpImg = cv.imread('/content/drive/MyDrive/PCVK/ab_ktp.jpeg')
editedImg = cv.cvtColor(ktpImg, cv.COLOR_BGR2RGB) # conversi BGR -> RGB

cv.rectangle(editedImg, (190, 190), (400, 210) , color=(255,255,0), thickness=-1)
cv.rectangle(editedImg, (190, 260), (300, 280) , color=(255,0,255), thickness=-1)

plt.imshow(editedImg)
