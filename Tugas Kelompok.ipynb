# %% [markdown]
# <a href="https://colab.research.google.com/github/LeToyek/2141720085-pcvk-2023/blob/main/Tugas%20Kelompok.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tugas Kelompok Minggu 2
#
# ## Anggota Kelompok
# 1. **Nama:** Adam Rafi Rezandi
#    - **NIM:** 2141720185
#    - **NO:** 02
#
# 2. **Nama:** Maulana Arif Wijaya
#    - **NIM:** 2141720085
#    - **NO:** 16
#
# 3. **Nama:** Mochamad Driya Ananta
#    - **NIM:** 2141720085
#    - **NO:** 17

# %%
import cv2 as cv
import matplotlib.pyplot as plt


ktpImg = cv.imread('/content/ab_ktp.jpeg')
editedImg = cv.cvtColor(ktpImg, cv.COLOR_BGR2RGB) # conversi BGR -> RGB

cv.rectangle(editedImg, (190, 190), (400, 210) , color=(255,255,0), thickness=-1)
cv.rectangle(editedImg, (190, 260), (300, 280) , color=(255,0,255), thickness=-1)

plt.imshow(editedImg)
